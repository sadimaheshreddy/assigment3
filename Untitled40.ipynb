# %%
Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.

PMF: The Probability Mass Function applies to discrete random variables. It gives the probability that a discrete random variable is exactly equal to some value.

Example: For a fair coin flip, the PMF for getting a head is 
𝑃
(
𝑋
=
1
)
=
0.5
P(X=1)=0.5, and the PMF for getting a tail is 
𝑃
(
𝑋
=
0
)
=
0.5
P(X=0)=0.5.
PDF: The Probability Density Function applies to continuous random variables. It gives the relative likelihood of a variable taking on a value, but not the exact probability (since it's continuous).

Example: For a normal distribution with mean 0 and standard deviation 1, the PDF at a point 
𝑥
x is given by the formula:
𝑓
(
𝑥
)
=
1
2
𝜋
exp
⁡
(
−
𝑥
2
2
)
f(x)= 
2π
​
 
1
​
 exp(− 
2
x 
2
 
​
 )
Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?

CDF: The Cumulative Distribution Function gives the probability that a random variable is less than or equal to a certain value. It’s the cumulative sum of probabilities up to that point.

Example: For a normal distribution with mean 0 and standard deviation 1, the CDF at 
𝑥
=
1
x=1 gives the probability that a random variable is less than or equal to 1.
Why CDF is used: CDF is used to find the probability that a random variable falls within a certain range, making it useful for probability calculations and hypothesis testing.

Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.

Examples:
Heights of people.
Test scores of students.
Measurement errors in scientific experiments.
Parameters:
Mean (μ): The center of the distribution (where the peak occurs).
Standard Deviation (σ): Controls the spread of the distribution. A larger σ results in a wider, flatter curve, while a smaller σ results in a narrower, taller curve.
Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution.

Importance: The normal distribution is important because it describes many natural phenomena and measurement errors. It’s used in statistical methods like hypothesis testing and confidence intervals.

Real-life examples:

IQ scores.
Blood pressure measurements.
Stock market returns.
Q5: What is Bernoulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial Distribution?

Bernoulli Distribution: A discrete probability distribution of a random variable which has two possible outcomes: success (1) and failure (0).

Example: Tossing a coin (heads = success, tails = failure).
Difference between Bernoulli and Binomial:

Bernoulli: Deals with a single trial (one coin flip).
Binomial: Deals with multiple independent trials (multiple coin flips) with a fixed probability of success for each trial.
Q6: Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally distributed, what is the probability that a randomly selected observation will be greater than 60? Use the appropriate formula and show your calculations.

First, calculate the z-score for 60:

𝑧
=
𝑥
−
𝜇
𝜎
=
60
−
50
10
=
1
z= 
σ
x−μ
​
 = 
10
60−50
​
 =1
Then, find the probability corresponding to a z-score of 1 using the z-table or a normal distribution calculator. The area to the left of z = 1 is approximately 0.8413. So, the probability of getting a value greater than 60 is:

𝑃
(
𝑋
>
60
)
=
1
−
𝑃
(
𝑋
≤
60
)
=
1
−
0.8413
=
0.1587
P(X>60)=1−P(X≤60)=1−0.8413=0.1587
Q7: Explain uniform Distribution with an example.

Uniform Distribution: A distribution where all outcomes are equally likely within a specified range.
Example: A fair die roll, where each side (1 through 6) has an equal probability of occurring.
Q8: What is the z-score? State the importance of the z-score.

Z-score: A z-score measures how many standard deviations a data point is away from the mean. It is calculated as:

𝑧
=
𝑥
−
𝜇
𝜎
z= 
σ
x−μ
​
 
Importance: The z-score allows comparison of values from different distributions, determines how unusual or typical a data point is, and helps in hypothesis testing and confidence intervals.

Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.

Central Limit Theorem: The theorem states that the distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the shape of the population distribution, provided the samples are independent and identically distributed (i.i.d.).

Significance: It allows us to make inferences about population parameters even when the population distribution is not normal, as long as we have a sufficiently large sample size.

Q10: State the assumptions of the Central Limit Theorem.

The samples are drawn randomly and independently.
The sample size is sufficiently large (usually n ≥ 30).
The population has a finite variance.
The samples are identically distributed (i.i.d.).
